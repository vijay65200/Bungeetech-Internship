# %%
import pandas as pd

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/main (1).csv")
df
# Out:
#          SKU  ...      COUNTRY
# 0      11331  ...  Switzerland
# 1      11331  ...    Hong Kong
# 2      11331  ...     USA (CA)
# 3      11331  ...    Hong Kong
# 4      11331  ...        Italy
# ...      ...  ...          ...
# 11191  11625  ...     USA (NY)
# 11192  11625  ...           UK
# 11193  11625  ...           UK
# 11194  11625  ...     USA (CA)
# 11195  11625  ...           UK
#
# [11196 rows x 9 columns]

# %%
result=df.loc[df['COUNTRY'].str.contains('USA')]
result.to_csv('output.csv',index=False)

# %%
df1=pd.read_csv("/content/output.csv")
df1
# Out:
#         SKU  ...   COUNTRY
# 0     11331  ...  USA (CA)
# 1     11332  ...  USA (CA)
# 2     11333  ...  USA (CA)
# 3     11333  ...  USA (MA)
# 4     11333  ...  USA (CA)
# ...     ...  ...       ...
# 3025  11625  ...  USA (CA)
# 3026  11625  ...  USA (CA)
# 3027  11625  ...  USA (FL)
# 3028  11625  ...  USA (NY)
# 3029  11625  ...  USA (CA)
#
# [3030 rows x 9 columns]
